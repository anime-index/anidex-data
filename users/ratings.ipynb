# %%
import pandas as pd

mal = pd.read_csv('data/user_anime000000000006.csv', sep='\t')

me = mal[mal.user_id=='andreu_vall']

me.head()
# Out:
#            user_id  anime_id  favorite  review_id review_date  \
# 30500  andreu_vall         1         0        NaN         NaN
# 30501  andreu_vall     10087         0        NaN         NaN
# 30502  andreu_vall     10162         0        NaN         NaN
# 30503  andreu_vall     10165         0        NaN         NaN
# 30504  andreu_vall     10408         0        NaN         NaN
#
#        review_num_useful  review_score  review_story_score  \
# 30500                NaN           NaN                 NaN
# 30501                NaN           NaN                 NaN
# 30502                NaN           NaN                 NaN
# 30503                NaN           NaN                 NaN
# 30504                NaN           NaN                 NaN
#
#        review_animation_score  review_sound_score  review_character_score  \
# 30500                     NaN                 NaN                     NaN
# 30501                     NaN                 NaN                     NaN
# ...

# %%
me.shape
# Out:
# (279, 16)

# %%
filtered = me.dropna(axis=1, how='all')

# %%
filtered.sort_values('last_interaction_date', ascending=False).head(60)
# Out:
#            user_id  anime_id  favorite  score         status  progress  \
# 30744  andreu_vall     50360         0    NaN  plan_to_watch       0.0
# 30725  andreu_vall     48569         0    7.0        on_hold      10.0
# 30710  andreu_vall     44961         0    5.0        dropped       5.0
# 30728  andreu_vall     48736         0    8.0       watching       7.0
# 30545  andreu_vall        21         0    9.0       watching    1011.0
# 30732  andreu_vall     49114         0    7.0       watching       7.0
# 30682  andreu_vall     40834         1   10.0       watching      19.0
# 30727  andreu_vall     48583         0    7.0       watching       7.0
# 30733  andreu_vall     49310         0    NaN  plan_to_watch       0.0
# 30639  andreu_vall     37987         0    9.0      completed       1.0
# 30718  andreu_vall     47778         0   10.0      completed      11.0
# 30664  andreu_vall     39741         0    8.0      completed       1.0
# ...

# %%
filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 279 entries, 30500 to 30778
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                279 non-null    object
#  1   anime_id               279 non-null    int64
#  2   favorite               279 non-null    int64
#  3   score                  188 non-null    float64
#  4   status                 279 non-null    object
#  5   progress               279 non-null    float64
#  6   last_interaction_date  256 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 17.4+ KB
